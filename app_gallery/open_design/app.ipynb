# %% [markdown]
# # Open Design
#
# Notebook-driven visual design app. The app skill owns the discovery, direction, artifact, and critique loop; the local library owns design-system and deck-theme assets.
