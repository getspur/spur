# %%
// evcxr smoke test
let xs: Vec<i32> = (1..=5).collect();
let sum: i32 = xs.iter().sum();
println!("sum(1..=5) = {sum}");
sum

# %%
# SPUR datasource setup cell v1
# This cell is managed by SPUR. Re-run it after datasource changes.
import duckdb

# No datasources are attached.
