# %% [markdown]
# # Explainer: SPUR Context + code_* / external_*
#
# **Project:** `context-service-code-explore`
# **Route:** `create`
# **Source page:** https://getspur.dev/context
# **Code source:** `crates/spur-context-service/`
# **Story spine:** How `code_*` (worktree) and `external_*` (context service) close the code-explore gap when dependency edges leave the repo.
#
# ---
#
# ## Gate 1 — Concept & layout (awaiting approval)
#
# Approve palette, typography, composition language, and pacing before Gate 2.

# %% [markdown]
# ## Scene ownership sketch (pre–Gate 2; not locked)
#
# | Scene | ~t | Primary owner | Claims |
# |---|---|---|---|
# | Open title | 0–4s | `palmier` | — |
# | Edges leave the worktree | 4–15s | `html-video` | C02, C06 |
# | Two planes | 15–28s | `html-video` | C03, C04, C05 |
# | Pinned identity | 28–36s | `html-video` | C08 |
# | Tool loop | 36–50s | `html-video` (+ optional `real-capture` later) | C09, C10, C11 |
# | CTA | 50–60s | `palmier` | C01 |
# | Full-length VO | 0–60s | `higgsfield` | all approved claims |
#
# ---
#
# ### Gate 1 decision needed
#
# Reply with:
#
# 1. **Direction:** A / B / C
# 2. **Duration:** 60s (default) or 45s
# 3. **Claim set:** all C01–C11, or list drops
# 4. **Proof:** concept-only (no real capture yet) **or** plan a real MCP capture beat later
#
# No paid generation until Gate 3.

# %% [markdown]
# ## Claim register (sourced — Gate 1)
#
# Only these claims may enter narration after approval. Each maps to an open-design source asset.
#
# | ID | Claim | Source |
# |---|---|---|
# | **C01** | SPUR Context Service is cloud code context for third-party packages. | getspur.dev/context hero; PRODUCT_AND_USAGE §1 |
# | **C02** | Your code has edges that leave the worktree; without external context, agents guess dependency APIs. | getspur.dev/context “The graph”; PRODUCT_AND_USAGE §2 Problem |
# | **C03** | Two planes: worktree tools answer “what’s in this repo?”; external tools answer “what’s in dependency X at version Y?” | getspur.dev/context “Two planes”; PRODUCT_AND_USAGE §1 table |
# | **C04** | Worktree plane uses `knowledge_context_pack_2` and `code_*`. | getspur.dev/context Worktree card; PRODUCT_AND_USAGE §1 |
# | **C05** | External plane uses `external_*` MCP tools served by Context Service. | getspur.dev/context External card; PRODUCT_AND_USAGE §1 |
# | **C06** | Without structured external context, agents fall back to web search, outdated docs, or guessing APIs across versions. | getspur.dev/context Why; PRODUCT_AND_USAGE §2 |
# | **C07** | Wrong dependency assumptions cause broken integrations, missed breaking changes, and rework. | PRODUCT_AND_USAGE §2; getspur.dev/context Why |
# | **C08** | Indexed unit identity is `(source, package, revision)`; selectors like `pkg:serde@1.0.197::Deserialize` pin version. | getspur.dev/context Identity; PRODUCT_AND_USAGE §3 |
# | **C09** | Tool loop: `external_knowledge_context` → `external_code_read` / `callers` / `callees`; cold revisions use `external_index` + status poll. | getspur.dev/context MCP tools + Cold path; PRODUCT_AND_USAGE §5 |
# | **C10** | Complements local intelligence; does not replace worktree `code_*`. Do not mix `pkg:` selectors into worktree `code_*`. | PRODUCT_AND_USAGE §2 Strategic fit + anti-patterns; getspur.dev/context Anti-patterns |
# | **C11** | Value: version-precise answers without cloning every crate; same graph-first workflow for agents. | PRODUCT_AND_USAGE §2 Value table; getspur.dev/context Why |
#
# **Source assets (open-design):**
# - `src-web-context` — https://getspur.dev/context (fetched 2026-07-20)
# - `src-product-usage` — `crates/spur-context-service/docs/PRODUCT_AND_USAGE.md`
# - `src-architecture` — `crates/spur-context-service/docs/ARCHITECTURE.md` (support only; no UI invention)

# %% [markdown]
# ## Locked brief (proposed — approve / edit)
#
# | Field | Value |
# |---|---|
# | **Audience** | Developers + coding-agent operators evaluating SPUR Context |
# | **Purpose** | Explain *why* code explore fails at dependency edges, and *how* worktree `code_*` + Context Service `external_*` complete the graph |
# | **Route** | `create` |
# | **Duration** | **60s** (recommended) or 45s tight cut |
# | **Aspect** | **16:9** (1920×1080) — site / LinkedIn / X |
# | **CTA** | Open `context.getspur.dev` · Docs at getspur.dev/docs |
# | **Tone** | Precise operator-grade; dark tech; no mascot; no fake UI as proof |
# | **Deliverables** | H.264/AAC MP4 + Palmier project + this notebook + delivery manifest |
# | **Rights** | Product page + crate docs owned; generated plates owned; no third-party stock without clearance |
#
# ### Narrative spine (3 beats)
#
# 1. **Problem** — In-repo edges resolve; dependency edges go dark → agents guess.
# 2. **Two planes** — Worktree (`knowledge_context_pack_2`, `code_*`) vs External (`external_*` via Context Service).
# 3. **Resolution** — Pinned `(source, package, revision)` graph + MCP tool loop: orient → read → callers/callees; index on demand when cold.
#
# ### Explicit non-claims (will not narrate)
#
# - Does not host private monorepos as the shared catalog.
# - Does not replace worktree tools for *your* code.
# - Is not “search the internet.”

# %% [markdown]
# ## Visual directions (pick one — Gate 1)
#
# Grounded in Open Design systems + SPUR dark operator brand from product launch.
#
# ### Direction A — **Graph Terminal** (Recommended)
# - **System:** Trading Terminal–leaning (`#0d0d0d` surfaces, cyan `#00D4AA` signal edges)
# - **Composition:** Node/edge diagrams; resolved vs unresolved edges; dual-plane split panels
# - **Typography:** Tight mono labels for tool names; sans headlines
# - **Pacing:** 60s; problem 0–15 · planes 15–32 · tool loop 32–50 · CTA 50–60
# - **Best for:** “edges go dark” metaphor + MCP tool precision
#
# ### Direction B — **Warm Warp Operator**
# - **System:** Warp-inspired warm near-black (`#353534` / `#faf9f6` ink)
# - **Composition:** Soft campfire dark; fewer hard grids; larger type
# - **Typography:** Humanist sans; mono only for selectors
# - **Pacing:** Slightly slower; more lifestyle of “operator at desk” inserts
# - **Best for:** Developer empathy, softer launch feel
#
# ### Direction C — **GitHub Diff Lab**
# - **System:** GitHub dark (`#0d1117`, blue `#0969da`)
# - **Composition:** Diff/PR mental model; “open edge” as unresolved review comment
# - **Typography:** System mono + clear hierarchy
# - **Pacing:** Dense; more table/tool inventory beats
# - **Best for:** Engineer-native credibility; higher information density
#
# ### Composition language (all directions)
# - **Real proof:** optional later real-capture of MCP tool JSON / TUI — never invent product UI as proof
# - **HTML plates:** concept graphs, two-plane diagram, selector anatomy, tool loop
# - **Higgsfield:** dry VO only (+ optional abstract atmosphere, no readable UI)
# - **Palmier:** titles, tool names as native text, end CTA
#
# ### Deliverable defaults
# - 16:9 · 60s · H.264/AAC · no captions unless requested · no music unless requested

# %% [markdown]
# ## Gate 1 — APPROVED
#
# | Decision | Value |
# |---|---|
# | **Direction** | **A · Graph Terminal** |
# | **Palette** | Near-black `#0d0d0d` / `#141414` surfaces · cyan `#00D4AA` resolved edges · muted gray unresolved · white/ink text |
# | **Typography** | Sans headlines · mono for tool names / selectors |
# | **Composition** | Node/edge diagrams · dual-plane split · resolved vs unresolved edges |
# | **Pacing** | 60s · problem 0–15 · planes 15–32 · tool loop 32–50 · CTA 50–60 |
# | **Duration / aspect** | 60s · 16:9 (1920×1080) |
# | **Claims** | C01–C11 (all) |
# | **Proof** | Concept-only (html-video + palmier + VO); no real-capture beat in v1 |
# | **CTA** | context.getspur.dev |
#
# Approved by user: Direction A (2026-07-20). Remaining brief fields locked to recommended defaults.

# %% [markdown]
# ## Gate 2 — Script & storyboard (awaiting approval)
#
# Narration uses **only** approved claims C01–C11. No product UI invention. Scene owners: `html-video` | `higgsfield` | `palmier`.
#
# ---
#
# ### Full VO script (dry, one voice) — ~60s · ~145 words
#
# **[0–4s · S01 open]**
# SPUR Context Service is cloud code context for third-party packages.
# *(C01)*
#
# **[4–15s · S02 problem]**
# Inside your repo, every call site resolves. The moment a symbol crosses into a dependency, the edge goes dark — and the agent guesses. Without structured external context, agents fall back to web search, outdated docs, or guessing APIs across versions. Wrong assumptions break integrations, miss breaking changes, and force rework.
# *(C02, C06, C07)*
#
# **[15–28s · S03 two planes]**
# Two planes, cleanly separated. In the worktree — this repository — you use knowledge context pack and code tools. For dependencies, you use the external MCP tools served by Context Service. Local tools answer what’s in this repo. External tools answer what’s in dependency X at version Y.
# *(C03, C04, C05)*
#
# **[28–36s · S04 identity]**
# Every indexed unit is source, package, and revision. Selectors pin the version — for example, serde at one-point-oh-dot-one-nine-seven, trait Deserialize. No stale docs. No cross-version drift.
# *(C08)*
# *Pronunciation:* serde = “sir-dee” · `1.0.197` = “one point oh one nine seven” · `pkg:` = “package selector”*
#
# **[36–50s · S05 tool loop]**
# Same graph-first workflow outside the worktree: orient with external knowledge context, then read real source, walk callers and callees. If a revision is cold, index on demand, keep working, and poll status — don’t block the session. Context complements local intelligence; it does not replace worktree code tools. Never feed package selectors into worktree reads.
# *(C09, C10, C11)*
#
# **[50–60s · S06 CTA]**
# Version-precise answers without cloning every crate. Open context dot get spur dot dev.
# *(C11, C01)*
#
# ---
#
# ### Pronunciation / style notes
#
# | Token | Say |
# |---|---|
# | `code_*` | “code tools” |
# | `external_*` | “external tools” |
# | `knowledge_context_pack_2` | “knowledge context pack” |
# | `MCP` | “M-C-P” |
# | `context.getspur.dev` | “context dot get spur dot dev” |
# | Dry VO | No music bed in VO file; no UI readout |

# %% [markdown]
# ### Scene graph (primary owner per scene)
#
# | Scene | Timeline | Owner | Assets to produce | Claim IDs |
# |---|---|---|---|---|
# | **S01 · Open** | 0.0–4.0s | `palmier` | Native title: “SPUR Context” / subtitle “Cloud code context for third-party packages” | C01 |
# | **S02 · Edges go dark** | 4.0–15.0s | `html-video` | Plate: worktree graph with glowing resolved edges; dependency nodes dim/unresolved; edge break animation | C02, C06, C07 |
# | **S03 · Two planes** | 15.0–28.0s | `html-video` | Plate: split panel WORKTREE (`code_*`) vs DEPENDENCIES (`external_*`); labels mono | C03, C04, C05 |
# | **S04 · Pinned identity** | 28.0–36.0s | `html-video` | Plate: anatomy of `pkg:serde@1.0.197::Deserialize` (source · package · revision) | C08 |
# | **S05 · Tool loop** | 36.0–50.0s | `html-video` | Plate: sequence chips — knowledge → search/read → callers/callees → (cold) index → status; anti-pattern “don’t cross planes” | C09, C10, C11 |
# | **S06 · CTA** | 50.0–60.0s | `palmier` | Native end card: CTA `context.getspur.dev` · Docs line optional | C01, C11 |
# | **VO track** | 0.0–60.0s | `higgsfield` | Single dry voice, segment-aligned to S01–S06 | all used |
#
# **Optional atmospheric (Gate 3 only if approved):** silent abstract network-glow B-roll under plates — no readable UI, logos, or claims (`higgsfield` insert, composited by Palmier).
#
# ### HTML plate specs (post–Gate 2)
#
# | Plate ID | Duration | Content |
# |---|---|---|
# | `plate-edges-dark` | 11.0s exact | Graph terminal aesthetic; resolved cyan edges → unresolved gray; worktree box + dependency box |
# | `plate-two-planes` | 13.0s exact | Dual column: Worktree tools vs External tools |
# | `plate-selector` | 8.0s exact | Selector string build-up; version pin highlight |
# | `plate-tool-loop` | 14.0s exact | Horizontal or vertical step flow of 5–6 tools; cold-path branch |
#
# All plates: self-contained HTML · no baked VO · Direction A palette · 1920×1080 · deterministic.
#
# ### Traceability (pre-manifest)
#
# ```
# src-web-context, src-product-usage
#   → C01–C11
#     → S01–S06.claim_ids
#       → plate-* / palmier titles / VO
# ```

# %% [markdown]
# ### Gate 2 decision needed
#
# Reply **approve** (or edit lines) for:
#
# 1. **VO script** as written (or mark cuts)
# 2. **Scene ownership map** S01–S06
# 3. **Four HTML plates** + Palmier open/end · no real-capture in v1
# 4. **Atmospheric B-roll:** yes / no (default **no** — plates only)
#
# After approval → render HTML plates (no paid gen) → Gate 3 for voice only.

# %% [markdown]
# ## Gate 2 — APPROVED
#
# | Decision | Value |
# |---|---|
# | VO script | As written (C01–C11 only) |
# | Scene map | S01–S06 ownership locked |
# | Plates | 4× html-video + Palmier open/end |
# | Real capture | None in v1 |
# | Atmospheric B-roll | **No** (default) |
# | Next | Render HTML plates → Gate 3 (voice only) |
#
# Approved by user 2026-07-20.

# %% [markdown]
# ## Source revalidation — 2026-07-20
#
# The approved claim set C01–C11 remains supported by current sources:
#
# - **Live product page:** `https://getspur.dev/context` still presents the worktree/external two-plane model, pinned `(source, package, revision)` identity, eight-tool MCP surface, on-demand cold indexing, and the “do not cross planes” rule.
# - **Product documentation:** `crates/spur-context-service/docs/PRODUCT_AND_USAGE.md` supports the problem, value, tool loop, selectors, authentication/scopes, and non-goals used in the script.
# - **Architecture documentation:** `crates/spur-context-service/docs/ARCHITECTURE.md` supports the frozen-snapshot serving model and ingest/serving split; these remain background evidence and are not added as narration claims.
# - **Current code bytes:** `crates/spur-context-service/src/mcp.rs::tool_definitions` exposes exactly `external_catalog`, `external_code_search`, `external_code_read`, `external_code_callers`, `external_code_callees`, `external_knowledge_context`, `external_index`, and `external_index_status`.
#
# No script or storyboard change is required. Gate 1 and Gate 2 remain locked. No paid generation has run.

# %% [markdown]
# ## Gate 3 — APPROVED · direct Higgsfield narration timing test complete
#
# **Approved contract:** `text2speech_v2` · `elevenlabs` · **Maya** preset · exact S01–S06 script · six dry segments · no music, captions, creative shots, or generated UI.
#
# | Scene | Slot | Attempt 1 | Approved retry | Best result | Decision |
# |---|---:|---:|---:|---:|---|
# | S01 | 4s | 6.32s | 4.32s | 4.32s | over by 0.32s |
# | S02 | 11s | 25.20s | 24.08s | 24.08s | over by 13.08s |
# | S03 | 13s | 21.28s | 22.72s | 21.28s | over by 8.28s |
# | S04 | 8s | 14.48s | 15.12s | 14.48s | over by 6.48s |
# | S05 | 14s | 25.28s | 25.36s | 25.28s | over by 11.28s |
# | S06 | 10s | 6.40s | — | 6.40s | fits; reusable |
#
# **Outcome:** all jobs completed. S01–S05 remain overlong after the single approved retry; their retry ceiling is exhausted. S06 fits. No additional paid generation was submitted.
#
# **Timing-test assets:** `deliveries/context-service-code-explore/audio/maya-timing-tests/`
#
# **Internal Higgsfield traceability (not delivery copy):**
# - S01: `11b071a0-550c-4e0a-b438-56c182629e46`, `7fe26011-d2cf-4cfe-9c71-e16bd0d0278f`
# - S02: `a16b2af9-f022-4b35-9113-040094e20dbb`, `8cb31029-fac3-4414-9e2d-4f743cf11c3f`
# - S03: `5d3f6e58-b9ca-4937-ae5f-f8dd3b9bd2d6`, `572c6990-9cb3-43b0-b765-e69e7c31d2de`
# - S04: `a5dc18ce-3e5c-43ad-9165-45b326b2fb4d`, `07779e5f-a2cf-4946-b635-5b2d8fe98274`
# - S05: `66266bac-df57-4314-b22d-c364416487cd`, `e80947b3-9c99-4686-a1b1-5bf2b2979740`
# - S06: `0ce9bcb8-9a32-4267-ada6-66b443dccc1c`
#
# **Editorial decision:** do not time-compress these takes into a robotic result. A tighter script is required to preserve Maya’s natural delivery and the approved 60-second runtime.

# %% [markdown]
# ## Timing recovery — APPROVAL REQUIRED · revised Gate 2 + paid prompt
#
# The measured Maya pace proves the original narration cannot fit the approved 60-second scene graph naturally. Recommended recovery: keep the locked 60-second format, preserve all core claims, reuse the fitting S06 take, and tighten S01–S05.
#
# | Scene | Slot | Proposed exact narration |
# |---|---:|---|
# | S01 | 0–4s | “SPUR Context Service is cloud code context for third-party packages.” |
# | S02 | 4–15s | “Inside your repo, symbols resolve. Cross into a dependency, and the edge goes dark. Agents guess from web search or stale docs — and integrations break.” |
# | S03 | 15–28s | “SPUR keeps two planes separate. Worktree context answers what’s in this repo. Context Service external tools answer what’s in dependency X at version Y.” |
# | S04 | 28–36s | “Each index is pinned by source, package, and revision — like Sir-dee one point oh one nine seven. No version drift.” |
# | S05 | 36–50s | “Use the same graph-first loop: orient, read source, then follow callers and callees. If a revision is cold, index it, keep working, and poll status. Never mix external selectors into worktree reads.” |
# | S06 | 50–60s | Reuse approved 6.40s take: “Version-precise answers without cloning every crate. Open context dot get spur dot dev.” |
#
# **Claims preserved:** C01–C11 remain grounded; this is compression, not a new claim set.
#
# **Updated paid-generation contract:** same model, engine, Maya voice, dry audio, and no creative shots. Generate one new take each for S01–S05; one retry only if a new take fails or overruns. Reuse S06.
#
# Reply **Approved** to approve both the revised Gate 2 script/storyboard timing and this updated paid prompt contract.

# %% [markdown]
# ## Voice audition — SELECTED · Maya
#
# **Purpose:** choose the least synthetic-sounding narrator before final S01–S06 generation.
#
# | Field | Approved value |
# |---|---|
# | Model | `text2speech_v2` |
# | Engine | `elevenlabs` |
# | Auditioned voices | Maya · Nora · Sienna |
# | Selected narrator | **Maya** |
# | Prompt | “Inside your repo, symbols resolve. Cross into a dependency, and the edge goes dark. Agents guess from web search or stale docs — and integrations break.” |
# | Retry ceiling | 0 |
# | Music / effects / other generation | None |
#
# | Voice | Duration | Audio |
# |---|---:|---|
# | **Maya — selected** | 11.60s | `deliveries/context-service-code-explore/audio/voice-audition/elevenlabs/maya.mp3` |
# | Nora | 14.48s | `deliveries/context-service-code-explore/audio/voice-audition/elevenlabs/nora.mp3` |
# | Sienna | 13.36s | `deliveries/context-service-code-explore/audio/voice-audition/elevenlabs/sienna.mp3` |
#
# **Selection:** Maya chosen by the user on 2026-07-20.
#
# **Media inspection:** MP3 · 44.1 kHz · mono for all three.
#
# The audition is complete. Maya is locked as narrator; final scene-aligned generation still requires approval of the revised exact script below.

# %% [markdown]
# ## Final Maya narration — COMPLETE · imported to PalmierPro
#
# **Approved contract:** `text2speech_v2` · `elevenlabs` · **Maya** preset · revised S01–S05 · reused S06 · dry audio · no music, captions, creative shots, or generated UI.
#
# | Scene | Slot | Selected duration | Result | Palmier clip |
# |---|---:|---:|---|---|
# | S01 | 0–4s | 4.32s | approved retry selected; starts at frame 0 and ends at frame 130 | `D1C9CA72` |
# | S02 | 4–15s | 10.08s | fits; begins immediately after S01 at frame 131 | `F2BF7B12` |
# | S03 | 15–28s | 10.32s | fits | `02911074` |
# | S04 | 28–36s | 7.60s | fits | `A86F69B1` |
# | S05 | 36–50s | 12.40s | fits | `F20A6BE3` |
# | S06 | 50–60s | 6.40s | reused approved take; fits | `386C45B4` |
#
# **Editorial handling:** S01’s retry ceiling is exhausted and its raw take is 0.32 seconds over the visual boundary. Palmier places S02 immediately after S01, so narration does not overlap. No voice speed-up or time compression was applied.
#
# **Local assets:** `deliveries/context-service-code-explore/audio/final-maya/`
#
# **Palmier project:** `SPUR Context Service — 60s` · timeline `8F0B47F0` · narration track A1.
#
# **Internal Higgsfield traceability:**
# - S01 initial: `eb3c5506-c4f4-48cb-ab94-9fa598518107`; selected retry: `3742a995-57bd-4eb2-a57d-cf2d15323b50`
# - S02: `ef9b9ff5-8403-45f9-95ef-04e82dfafa06`
# - S03: `4243fd39-fdb6-4fde-b333-3b2fd6c1fd06`
# - S04: `4c9c271d-b416-4136-9c76-0b7dd8afeb94`
# - S05: `d0672fe1-6e20-4890-8542-9b184d668cfb`
# - S06: reuse recorded in the prior Maya timing-test cell
#
# **Status:** six narration assets are preserved, inspected, imported, and placed. No additional paid generation was submitted.

# %% [markdown]
# ## Picture assembly progress — Palmier-native sections
#
# **Status:** title and CTA completed; HTML motion plates remain blocked on renderer capability.
#
# - Project: `SPUR Context Service — 60s`
# - Timeline: `8F0B47F0`, 1920×1080, 30 fps, 1,800-frame picture bed
# - Background owner: Palmier matte `#0D0D0D`, frames 0–1800
# - Title owner: Palmier text, frames 0–120
#   - `[ SPUR CONTEXT SERVICE ]` in mono cyan `#00D4AA`
#   - `Cloud context for / third-party packages.` in bold sans
# - CTA owner: Palmier text, frames 1500–1800
#   - `Version-precise answers. / No cloning required.`
#   - `context.getspur.dev →`
# - Visual inspection: title verified at frames 60 and 110; CTA verified at frames 1600 and 1750.
#
# ### HTML-video gate
#
# The current tool session exposes notebook editing but does **not** expose `html_video_search_templates`, `html_video_get_template`, or `html_video_render`. Per the HTML-video skill contract, the four approved plates cannot be rendered through an alternate path.
#
# Pending plates:
# 1. `plate-edges-dark` — 11 s
# 2. `plate-two-planes` — 13 s
# 3. `plate-selector` — 8 s
# 4. `plate-tool-loop` — 14 s

# %% [markdown]
# # AC Deal Desk — Frontend Design Audit
#
# **Brief (locked from review request)**
#
# | Field | Value |
# |---|---|
# | Surface | AC console UI audit + interactive critique board |
# | Audience | Product + eng reviewing implementation quality |
# | Tone | Systems-dense, operational, Vietnamese-first UI |
# | Brand | Otobank AC tokens (`brand`, `primary`, `muted`, mono scores) |
# | Scale | Inbox chips → Lead workspace three lenses → AI draft panel |
# | Scope | `ac-deal-desk-map.tsx` (~1.8k LOC) + model + inbox/lead integration |
#
# **Not building a new product** — auditing shipped R1 frontend against the three-lens contract and AC workflow.

# %%
// open-design artifact: AC Deal Desk frontend audit board
const html = String.raw`<!DOCTYPE html>
<html lang="vi">
<head>
<meta charset="utf-8" />
<meta name="viewport" content="width=device-width, initial-scale=1" />
<title>AC Deal Desk — Frontend Design Audit</title>
<style>
  :root {
    --page: #0f1419;
    --card: #171d25;
    --elevated: #1e2630;
    --border: #2a3441;
    --brand: #3d9cf0;
    --brand-dim: rgba(61,156,240,.12);
    --primary: #e8eef5;
    --secondary: #b7c2cf;
    --muted: #7d8b9a;
    --warning: #e6b84d;
    --danger: #f07178;
    --success: #7fd99a;
    --info: #6cb6ff;
    --mono: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace;
    --display: "Iowan Old Style", "Palatino Linotype", Palatino, Georgia, serif;
    --sans: "Segoe UI", system-ui, -apple-system, sans-serif;
  }
  * { box-sizing: border-box; }
  body {
    margin: 0; padding: 24px;
    font-family: var(--sans);
    background: radial-gradient(1200px 600px at 10% -10%, #1a2740 0%, var(--page) 55%);
    color: var(--primary);
    line-height: 1.45;
  }
  .wrap { max-width: 1180px; margin: 0 auto; display: grid; gap: 18px; }
  .eyebrow {
    font-family: var(--mono); font-size: 11px; letter-spacing: .18em;
    text-transform: uppercase; color: var(--brand); font-weight: 700;
  }
  h1 { font-family: var(--display); font-size: 28px; margin: 6px 0 0; letter-spacing: -0.02em; }
  h2 { font-family: var(--display); font-size: 18px; margin: 0 0 10px; }
  h3 { font-size: 13px; margin: 0 0 8px; color: var(--secondary); font-weight: 700; }
  p, li { color: var(--secondary); font-size: 13px; }
  .card {
    background: linear-gradient(180deg, rgba(255,255,255,.02), transparent),
                var(--card);
    border: 1px solid var(--border);
    border-radius: 16px;
    padding: 16px 18px;
  }
  .grid-3 { display: grid; grid-template-columns: repeat(3, 1fr); gap: 12px; }
  .grid-2 { display: grid; grid-template-columns: 1.1fr .9fr; gap: 14px; }
  @media (max-width: 900px) {
    .grid-3, .grid-2 { grid-template-columns: 1fr; }
  }
  .score {
    display: flex; align-items: baseline; gap: 8px;
  }
  .score b {
    font-family: var(--mono); font-size: 28px; color: var(--primary);
  }
  .score span { color: var(--muted); font-size: 12px; }
  .pill {
    display: inline-flex; align-items: center; gap: 6px;
    border-radius: 999px; border: 1px solid var(--border);
    background: var(--elevated); padding: 4px 10px;
    font-family: var(--mono); font-size: 10px; color: var(--secondary);
  }
  .pill.ok { border-color: rgba(127,217,154,.35); color: var(--success); background: rgba(127,217,154,.08); }
  .pill.warn { border-color: rgba(230,184,77,.35); color: var(--warning); background: rgba(230,184,77,.08); }
  .pill.bad { border-color: rgba(240,113,120,.35); color: var(--danger); background: rgba(240,113,120,.08); }
  .pill.brand { border-color: rgba(61,156,240,.4); color: var(--brand); background: var(--brand-dim); }
  .bar {
    height: 8px; border-radius: 999px; background: #243041; overflow: hidden;
  }
  .bar > i { display: block; height: 100%; background: linear-gradient(90deg, var(--brand), #7ec8ff); }
  .dims { display: grid; gap: 10px; }
  .dim {
    display: grid; grid-template-columns: 140px 1fr 48px; gap: 10px; align-items: center;
  }
  .dim label { font-size: 12px; color: var(--muted); }
  .mock {
    background: #121820; border: 1px solid var(--border); border-radius: 14px; padding: 12px;
    display: grid; gap: 10px;
  }
  .mock-header { display: flex; justify-content: space-between; gap: 8px; align-items: start; }
  .mock-title { font-family: var(--display); font-size: 16px; font-weight: 700; }
  .chips { display: flex; flex-wrap: wrap; gap: 6px; }
  .chip {
    border-radius: 999px; border: 1px solid var(--border); background: var(--elevated);
    padding: 3px 8px; font-size: 10px; color: var(--secondary); font-family: var(--mono);
  }
  .chip.brand { border-color: rgba(61,156,240,.45); background: var(--brand-dim); color: var(--brand); }
  .chip.warn { border-color: rgba(230,184,77,.4); color: var(--warning); }
  .path {
    border: 1px solid var(--border); border-radius: 12px; padding: 10px; background: var(--card);
  }
  .path.sel { border-color: rgba(61,156,240,.55); background: var(--brand-dim); }
  .path-top { display: flex; justify-content: space-between; gap: 8px; }
  .scorebox {
    background: var(--brand); color: #041018; border-radius: 10px; padding: 6px 8px; text-align: center;
    min-width: 44px;
  }
  .scorebox b { display: block; font-size: 16px; font-family: var(--display); }
  .scorebox small { font-family: var(--mono); font-size: 8px; text-transform: uppercase; opacity: .85; }
  .tabs { display: flex; flex-wrap: wrap; gap: 6px; }
  .tab {
    border-radius: 999px; border: 1px solid var(--border); padding: 5px 10px; font-size: 11px;
    color: var(--muted); background: var(--elevated);
  }
  .tab.on { border-color: rgba(61,156,240,.5); color: var(--brand); background: var(--brand-dim); font-weight: 700; }
  .posture {
    display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 8px;
  }
  .posture > div {
    border: 1px solid var(--border); border-radius: 10px; padding: 8px; background: var(--card);
  }
  .posture > div.rec { border-color: rgba(61,156,240,.5); background: var(--brand-dim); }
  .posture b { display: block; font-size: 13px; font-family: var(--display); margin-top: 4px; }
  .ai-banner {
    border: 1px solid rgba(108,182,255,.35); background: rgba(108,182,255,.08);
    border-radius: 10px; padding: 8px 10px; font-size: 11px; color: var(--info);
  }
  .obj {
    border: 1px solid rgba(61,156,240,.4); background: var(--brand-dim);
    border-radius: 10px; padding: 10px; font-size: 12px;
  }
  .finding {
    border-left: 3px solid var(--border); padding: 8px 10px; margin: 0 0 8px;
    background: var(--elevated); border-radius: 0 10px 10px 0;
  }
  .finding.p0 { border-left-color: var(--danger); }
  .finding.p1 { border-left-color: var(--warning); }
  .finding.p2 { border-left-color: var(--brand); }
  .finding strong { display: block; font-size: 12px; margin-bottom: 3px; }
  .meta { font-family: var(--mono); font-size: 10px; color: var(--muted); }
  .flow {
    display: flex; flex-wrap: wrap; gap: 8px; align-items: center;
  }
  .node {
    border: 1px solid var(--border); background: var(--elevated); border-radius: 10px;
    padding: 8px 10px; font-size: 11px; min-width: 120px;
  }
  .node b { display: block; color: var(--primary); font-size: 12px; }
  .arrow { color: var(--muted); font-family: var(--mono); }
  table { width: 100%; border-collapse: collapse; font-size: 12px; }
  th, td { text-align: left; padding: 7px 6px; border-bottom: 1px solid var(--border); vertical-align: top; }
  th { color: var(--muted); font-weight: 600; font-size: 10px; text-transform: uppercase; letter-spacing: .08em; }
  code { font-family: var(--mono); font-size: 10px; color: var(--brand); }
</style>
</head>
<body>
<div class="wrap">
  <header class="card">
    <div class="eyebrow">Open Design · Frontend audit</div>
    <h1>AC Deal Desk — R1 implementation check</h1>
    <p style="margin:8px 0 12px;max-width:70ch">
      Audit of shipped Expo UI: <code>ac-deal-desk-map.tsx</code> + model helpers, wired into
      <code>inbox.tsx</code> and <code>leads/[id].tsx</code>. Three-lens product packet,
      rules-first authority, manual-only AI drafts.
    </p>
    <div class="chips">
      <span class="pill brand">Surface: AC console</span>
      <span class="pill ok">Data product: strong</span>
      <span class="pill warn">AI draft UX: honest but dense</span>
      <span class="pill ok">Safety: manual_only locked</span>
      <span class="pill">File ~1.8k LOC · single module</span>
    </div>
  </header>

  <section class="grid-3">
    <div class="card">
      <h3>Overall craft</h3>
      <div class="score"><b>7.6</b><span>/ 10 systems</span></div>
      <div class="bar" style="margin-top:10px"><i style="width:76%"></i></div>
      <p style="margin:10px 0 0">Solid operational density. Vietnamese AC voice is consistent. Structure matches Part1 / Part2 product cut.</p>
    </div>
    <div class="card">
      <h3>Trust / safety UX</h3>
      <div class="score"><b>8.8</b><span>/ 10</span></div>
      <div class="bar" style="margin-top:10px"><i style="width:88%"></i></div>
      <p style="margin:10px 0 0">No fake data when flag off. Safety receipt gates copy. Provenance + fallback visible. R1 boundary copy is explicit.</p>
    </div>
    <div class="card">
      <h3>Mobile three-pane</h3>
      <div class="score"><b>7.0</b><span>/ 10</span></div>
      <div class="bar" style="margin-top:10px"><i style="width:70%"></i></div>
      <p style="margin:10px 0 0">Focus panes work, but selecting a path jumps to “decide” and hides evidence — easy to lose the “why” loop on phone.</p>
    </div>
  </section>

  <section class="card">
    <h2>Implementation map</h2>
    <div class="flow" style="margin-bottom:12px">
      <div class="node"><b>Inbox</b>chips + priority sort + feature states</div>
      <span class="arrow">→</span>
      <div class="node"><b>Lead detail</b>DealDeskLeadWorkspace</div>
      <span class="arrow">→</span>
      <div class="node"><b>1 Paths</b>PathSelector list</div>
      <span class="arrow">→</span>
      <div class="node"><b>2 Evidence</b>prior · gaps · why</div>
      <span class="arrow">→</span>
      <div class="node"><b>3 Decide</b>NegotiationLens + AiDraftPanel</div>
    </div>
    <table>
      <thead><tr><th>Component</th><th>Role</th><th>State craft</th><th>Note</th></tr></thead>
      <tbody>
        <tr>
          <td><code>DealDeskInboxMapChips</code></td>
          <td>Composite priority · prior · paths · missing</td>
          <td><span class="pill ok">good</span></td>
          <td>Compact triage signal; a11y label is thoughtful.</td>
        </tr>
        <tr>
          <td><code>DealDeskInboxFeatureState</code></td>
          <td>loading / disabled / failed / empty / partial</td>
          <td><span class="pill ok">excellent</span></td>
          <td>Explains 25-map window — rare honesty for ops UIs.</td>
        </tr>
        <tr>
          <td><code>DealDeskLeadWorkspace</code></td>
          <td>Orchestrates lenses + exposure feedback</td>
          <td><span class="pill ok">good</span></td>
          <td>selectPath forces focusPane=decide (mobile tradeoff).</td>
        </tr>
        <tr>
          <td><code>SelectedPathEvidence</code></td>
          <td>Prior breakdown, reasons, gaps, assumptions</td>
          <td><span class="pill brand">strong</span></td>
          <td>Disclosure sections keep density manageable.</td>
        </tr>
        <tr>
          <td><code>NegotiationLens</code></td>
          <td>Worth map + 3 price postures</td>
          <td><span class="pill ok">good</span></td>
          <td>Clear “no listing mutation” framing.</td>
        </tr>
        <tr>
          <td><code>AiDraftPanel</code></td>
          <td>Scripts, copy, regen tones, grounding</td>
          <td><span class="pill warn">heavy</span></td>
          <td>~390 LOC panel; many disclosures; safety first is correct.</td>
        </tr>
        <tr>
          <td><code>DraftProvenance</code></td>
          <td>provider · mode · fallback</td>
          <td><span class="pill ok">good</span></td>
          <td>Mono provider strings are eng-facing; AC may want softer labels.</td>
        </tr>
      </tbody>
    </table>
  </section>

  <section class="grid-2">
    <div class="card">
      <h2>UI reconstruction — three lenses</h2>
      <div class="mock">
        <div class="mock-header">
          <div>
            <div class="eyebrow">Deal Desk · R1</div>
            <div class="mock-title">Không gian đường đi cho lead</div>
            <div class="meta" style="margin-top:4px">6 hướng xe · prior 5/100 · dữ liệu thật</div>
          </div>
          <div class="chips">
            <span class="chip">Làm mới</span>
            <span class="chip brand">Liên hệ</span>
          </div>
        </div>
        <div class="tabs">
          <span class="tab on">1 · Chọn hướng</span>
          <span class="tab">2 · Kiểm chứng</span>
          <span class="tab">3 · Quyết định &amp; soạn lời</span>
        </div>
        <div class="path sel">
          <div class="path-top">
            <div>
              <div class="eyebrow">Hướng 1</div>
              <div style="font-weight:700;margin-top:2px">Kia Telluride Hybrid 2027</div>
              <div class="meta">Đồng Nai · 46 km · SUV</div>
            </div>
            <div class="scorebox"><b>59</b><small>điểm</small></div>
          </div>
          <div class="chips" style="margin-top:8px">
            <span class="chip">Fit 55%</span>
            <span class="chip">Ngân sách 100%</span>
            <span class="chip">Giá 1,16 tỷ</span>
          </div>
        </div>
        <div class="path">
          <div class="path-top">
            <div>
              <div class="eyebrow">Hướng 2</div>
              <div style="font-weight:700;margin-top:2px">Toyota Fortuner 2024</div>
              <div class="meta">HCMC · 9.000 km · SUV</div>
            </div>
            <div class="scorebox" style="background:#2a3a4d;color:var(--primary)"><b>54</b><small>điểm</small></div>
          </div>
        </div>
        <div class="posture">
          <div><span class="meta">Bán nhanh</span><b>1,11 tỷ</b></div>
          <div class="rec"><span class="meta">Cân bằng · đề xuất</span><b>1,16 tỷ</b></div>
          <div><span class="meta">Tối đa</span><b>1,23 tỷ</b></div>
        </div>
        <div class="ai-banner">Chỉ sao chép · không tự gửi · fallback local_rules nếu Bedrock chặn</div>
        <div class="obj">
          <div class="meta">MỤC TIÊU CUỘC GỌI</div>
          <div style="margin-top:4px;color:var(--primary)">Xác minh nhu cầu và thống nhất bước tiếp theo dựa trên map Otobank.</div>
        </div>
      </div>
      <p class="meta" style="margin-top:10px">Reconstruction mirrors PathSelector + NegotiationLens + AiDraftPanel hierarchy.</p>
    </div>

    <div class="card">
      <h2>Critique dimensions</h2>
      <div class="dims">
        <div class="dim">
          <label>Hierarchy</label>
          <div class="bar"><i style="width:78%"></i></div>
          <span class="meta">7.8</span>
        </div>
        <div class="dim">
          <label>Density</label>
          <div class="bar"><i style="width:82%"></i></div>
          <span class="meta">8.2</span>
        </div>
        <div class="dim">
          <label>State honesty</label>
          <div class="bar"><i style="width:92%"></i></div>
          <span class="meta">9.2</span>
        </div>
        <div class="dim">
          <label>Safety UX</label>
          <div class="bar"><i style="width:90%"></i></div>
          <span class="meta">9.0</span>
        </div>
        <div class="dim">
          <label>Mobile craft</label>
          <div class="bar"><i style="width:68%"></i></div>
          <span class="meta">6.8</span>
        </div>
        <div class="dim">
          <label>AI legibility</label>
          <div class="bar"><i style="width:72%"></i></div>
          <span class="meta">7.2</span>
        </div>
      </div>
      <h3 style="margin-top:16px">What works</h3>
      <ul>
        <li>Feature-off / empty / partial / failed states never invent maps.</li>
        <li>R1 boundary note + “không tự gửi” is product-correct.</li>
        <li>Mono version stamps (ranker, pricing, policy) build engineer trust without cluttering primary labels.</li>
        <li>Copy blocked until safety receipt is complete — rare and correct.</li>
        <li>Inbox chips + composite priority make map data actionable outside detail page.</li>
      </ul>
    </div>
  </section>

  <section class="card">
    <h2>Findings backlog</h2>

    <div class="finding p0">
      <strong>P0 — Mobile path select skips evidence lens</strong>
      <code>DealDeskLeadWorkspace.selectPath</code> sets <code>focusPane = "decide"</code>. On small screens evidence is hidden.
      AC sees scores then jumps to scripts without “why / gaps”. Prefer landing on <code>evidence</code> first, or keep a sticky why strip.
    </div>

    <div class="finding p1">
      <strong>P1 — AiDraftPanel cognitive load</strong>
      Opening → arc → channels → questions → dont_say → timeline → objections → grounding is a wall.
      Default to a “Call card” (objective + opening + next action + copy) and bury the rest under one “Chi tiết kịch bản” disclosure.
    </div>

    <div class="finding p1">
      <strong>P1 — Provenance is engineer dialect</strong>
      Strings like <code>provider local_rules · provider_mode sandbox_fallback · tone balanced</code> are accurate but not AC-native.
      Map to: “Bản nháp nội bộ (dự phòng)” / “AI nhà cung cấp” with detail expandable.
    </div>

    <div class="finding p1">
      <strong>P1 — Draft capability vs path binding</strong>
      When draft is bound to another path, UI correctly explains it — but regen controls only appear when capability is ready.
      If provenance is fallback/local_rules, AC still gets a plan; ensure “Viết ngắn hơn / Trang trọng hơn” remains available whenever plan exists and API allows.
    </div>

    <div class="finding p2">
      <strong>P2 — Module weight</strong>
      Single ~1.8k-line feature file owns inbox + workspace + AI. Split: <code>inbox</code>, <code>paths</code>, <code>evidence</code>, <code>ai-draft</code> for reviewability and design iteration speed.
    </div>

    <div class="finding p2">
      <strong>P2 — English rationale leakage risk</strong>
      Localization map covers many keys; residual English from API rationale strings can surface in posture/why.
      Keep a design QA pass on live map payloads for VI completeness.
    </div>

    <div class="finding p2">
      <strong>P2 — Inbox chip semantics</strong>
      “ƯT” composite priority is powerful but unexplained on first use.
      Add tooltip / one-line “ƯT = prior × top path” near chips.
    </div>
  </section>

  <section class="grid-2">
    <div class="card">
      <h2>Anti-slop check (implementation)</h2>
      <ul>
        <li>No Lorem / placeholder customer data in empty states.</li>
        <li>No decorative gradients in product UI — token surfaces only.</li>
        <li>Real Vietnamese operational copy, not marketing fluff.</li>
        <li>Numbers are mono; scores scannable.</li>
        <li>Safety language is repeated deliberately (boundary), not purple prose.</li>
      </ul>
    </div>
    <div class="card">
      <h2>Recommended next design moves</h2>
      <ol>
        <li><b>Call card first</b> for AiDraftPanel default view.</li>
        <li><b>Evidence-first mobile selection</b> after path tap.</li>
        <li><b>Humanize provenance</b> with expandable eng detail.</li>
        <li><b>Split file</b> by lens for faster visual iteration.</li>
        <li><b>Chip legend</b> for ƯT/Prior/Hướng/Thiếu.</li>
      </ol>
    </div>
  </section>

  <footer class="card">
    <div class="meta">Sources: apps/app/features/ac-deal-desk-map.tsx · ac-deal-desk-map.model.ts · app/(ac)/inbox.tsx · app/(ac)/leads/[id].tsx</div>
    <div class="meta" style="margin-top:4px">Open Design audit · systems specialty · R1 recommend-only contract</div>
  </footer>
</div>
</body>
</html>`;

await Deno.jupyter.display({
  "text/html": html,
}, { raw: true });
# Out:
# <!DOCTYPE html>
# <html lang="vi">
# <head>
# <meta charset="utf-8" />
# <meta name="viewport" content="width=device-width, initial-scale=1" />
# <title>AC Deal Desk — Frontend Design Audit</title>
# <style>
#   :root {
#     --page: #0f1419;
#     --card: #171d25;
#     --elevated: #1e2630;
#     --border: #2a3441;
#     --brand: #3d9cf0;
#     --brand-dim: rgba(61,156,240,.12);
#     --primary: #e8eef5;
#     --secondary: #b7c2cf;
#     --muted: #7d8b9a;
#     --warning: #e6b84d;
#     --danger: #f07178;
#     --success: #7fd99a;
#     --info: #6cb6ff;
#     --mono: ui-monospace, SFMono-Regular, Menlo, Consolas, monospace;
#     --display: "Iowan Old Style", "Palatino Linotype", Palatino, Georgia, serif;
#     --sans: "Segoe UI", system-ui, -apple-system, sans-serif;
#   }
#   * { box-sizing: border-box; }
#   body {
#     margin: 0; padding: 24px;
#     font-family: var(--sans);
#     background: radial-gradient(1200px 600px at 10% -10%, #1a2740 0%, var(--page) 55%);
# ...

# %% [markdown]
# ## Plan
#
# 1. Map implementation structure (inbox · workspace · three panes · AI panel)
# 2. Score against five critique dims: hierarchy, density, state honesty, safety UX, mobile craft
# 3. Render audit board HTML: structure diagram + UI reconstruction + findings
# 4. Rank fix backlog (P0/P1/P2) tied to real files/symbols
